# %% [markdown]
# imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import pickle
import gc

# %% [markdown]
# ### Para guardar os dados em disco

# %%
def save_pkl(data, path):
    try:
        with open(path, "wb") as saved_data:
            pickle.dump(data, saved_data)
    except:
        print('Fail to save data')

def load_pkl(path):
    try:
        with open(path, "rb") as loaded_data:
            to_return = pickle.load(loaded_data)
            return to_return
    except:
        print('Fail to load data')
        return None

# %% [markdown]
# meta data

# %%
df = pd.read_csv("../UrbanSound8K/metadata/UrbanSound8K.csv")
df.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %% [markdown]
# distribuição das classes

# %%
df['class'].value_counts().plot(kind='pie', autopct='%1.0f%%', figsize=(4,4))
plt.title('Class Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# feature extraction and pre-processing

# %% [markdown]
# Padding of the Audio to a Fixed Length

# %%
import os

def padding(path, duration = 4, sr = 22050, files_limit = -1, verbose = False):
    files = librosa.util.find_files(path)
    data = []

    for index, file_path in enumerate(files):
        if files_limit != -1 and index >= files_limit:
            break
        if verbose:
            print(f"Processing audio {index + 1}/{len(files)}")
        try:
            audio, _ = librosa.load(file_path, sr=sr, mono=True)

            audio = np.pad(audio, (0, max(0, duration*sr - len(audio))), mode='constant')
            audio = audio[:duration * sr]

            file_name = os.path.basename(file_path)
            data.append([file_name, audio])
        
        except Exception:
            print(f"Error in processig file {file_path}: {Exception}")

    return data

# %% [markdown]
# feature extraction

# %%
def feature_extraction(dataframe, audios, hop_length = 512, n_fft = 256):
    mfcc_coeficients = []
    labels = []

    for index in range(len(audios)):
        try:
            file_name =audios[index][0]
            if file_name:
                row = dataframe.loc[dataframe["slice_file_name"] == file_name]

                if not row.empty:
                    label = row.iloc[0,6]
                    mfcc = librosa.feature.mfcc(
                        y = np.array(audios[index][1]),
                        n_mfcc = 13, 
                        sr = 22050,
                        hop_length = 1024
                    )
                    # Normalizing mfcc using mean variance
                    mfcc = (mfcc - np.mean(mfcc, axis = 1, keepdims = True)) / (np.std(mfcc, axis = 1, keepdims = True) + 1e-6)
                    mfcc_coeficients.append(mfcc)
                    labels.append(label)
        except Exception:
            print(f"Error in processig file {audios[index][0]}: {Exception}")

    mfcc_coeficients = np.array(mfcc_coeficients)
    labels = np.array(labels)
    return mfcc_coeficients, labels

# %% [markdown]
# data normalization and pre-processing

# %%
fold_paths = ["../UrbanSound8K/audio/fold1",
              "../UrbanSound8K/audio/fold2",
              "../UrbanSound8K/audio/fold3",
              "../UrbanSound8K/audio/fold4",
              "../UrbanSound8K/audio/fold5",
              "../UrbanSound8K/audio/fold6",
              "../UrbanSound8K/audio/fold7",
              "../UrbanSound8K/audio/fold8",
              "../UrbanSound8K/audio/fold9",
              "../UrbanSound8K/audio/fold10"]

# %%
features = np.empty((10,), dtype=object)
label = np.empty((10,), dtype=object)

for i, fold in enumerate(fold_paths):
    print(f"Processing Fold Number {i+1}")
    audio_data = padding(fold)

    mfcc, labels = feature_extraction(df, audio_data)
    mfcc = mfcc.transpose(0, 2, 1)
    
    
    encoded_labels = np.zeros((len(labels), 10))
    encoded_labels[np.arange(len(labels)), labels] = 1
    
    features[i] = mfcc
    label[i] = encoded_labels
    print("Features Shape: ",features[i].shape)
    print("Labels Shape: ",label[i].shape,"\n")
    
    del mfcc
    del encoded_labels
    gc.collect() # libertar memoria
# Out:
# Processing Fold Number 1
# Features Shape:  (873, 87, 13)
# Labels Shape:  (873, 10)
#
# Processing Fold Number 2
# Features Shape:  (888, 87, 13)
# Labels Shape:  (888, 10)
#
# Processing Fold Number 3
# Features Shape:  (925, 87, 13)
# Labels Shape:  (925, 10)
#
# Processing Fold Number 4
# Features Shape:  (990, 87, 13)
# Labels Shape:  (990, 10)
#
# Processing Fold Number 5
# Features Shape:  (936, 87, 13)
# Labels Shape:  (936, 10)
#
# Processing Fold Number 6
# Features Shape:  (823, 87, 13)
# Labels Shape:  (823, 10)
#
# Processing Fold Number 7
# Features Shape:  (838, 87, 13)
# Labels Shape:  (838, 10)
#
# Processing Fold Number 8
# Features Shape:  (806, 87, 13)
# Labels Shape:  (806, 10)
#
# Processing Fold Number 9
# Features Shape:  (816, 87, 13)
# Labels Shape:  (816, 10)
#
# Processing Fold Number 10
# Features Shape:  (837, 87, 13)
# Labels Shape:  (837, 10)

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# #### 1. Input Layer
# - Shape: (x, y) where:
#   - x is the number of timesteps (sequence length).
#   - y is the number of features per timestep (e.g., MFCC coefficients).
# - Purpose: The model expects a sequential input where each timestep represents a feature vector of the audio signal.
# #### 2. First Bidirectional LSTM Layer
# Description: A Bidirectional LSTM with 128 units.
# - Bidirectionality: Processes the sequence in both forward and backward directions to capture dependencies in the audio signal from past and future timesteps.
# - Activation: tanh for non-linearity.
# - Kernel Initialization: glorot_uniform for balanced weight initialization.
# - Output: Produces a sequence of 128 features for each timestep.
# - Dropout (0.3): <b>Randomly drops 30% of connections to prevent overfitting.</b>
# - Batch Normalization: <b>Normalizes the output of the LSTM layer, ensuring stability during training by keeping activations in a consistent range.</b>
#
# #### 3. Second Bidirectional LSTM Layer
# Description: Another Bidirectional LSTM with 128 units.
# - Purpose: Further refines temporal features extracted from the first LSTM layer, learning more complex patterns.
# - Output: Produces a sequence of 128 features for each timestep.
# - Dropout (0.3): <b>Again, drops 30% of connections for regularization.</b>
# - Batch Normalization: <b>Stabilizes activations and accelerates convergence.</b>
#
# #### 4. TimeDistributed Dense Layers
# Description: Fully connected layers applied independently to each timestep. These layers transform the feature representation at each timestep into higher-level abstractions.
# - First Dense Layer:
#   - Units: 128 neurons.
#   - Activation: ReLU for faster training and reduced vanishing gradient issues.
#   - Regularization: L2 regularization (0.01) to prevent overfitting.
#   - Dropout (0.2): Drops 20% of connections.
# - Second Dense Layer:
#   - Units: 64 neurons.
#   - Activation: ReLU.
#   - Regularization: L2 regularization (0.01).
#   - Dropout (0.2).
#   - Purpose: These layers learn high-level feature transformations for each timestep.
#
# #### 5. Flatten Layer
# Description: Flattens the outputs of the TimeDistributed Dense layers into a single vector.
# - Purpose: Converts the 2D sequence of features into a 1D vector suitable for final classification.
#
# #### 6. Output Layer
# Description: A fully connected Dense layer with 10 neurons.
# - Activation: Softmax, which outputs a probability distribution over the 10 sound classes.
# - Purpose: Final classification into one of the 10 categories.

# %%
# from tensorflow.keras import Sequential, regularizers, layers
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, TimeDistributed, Flatten, BatchNormalization

# def create_bidirectional_model(x, y):
#     input_shape = (x, y)  # Shape of X_train sample

#     model = Sequential()

#     # First Bidirectional LSTM layer
#     model.add(Bidirectional(LSTM(64, return_sequences=True, activation='tanh', kernel_initializer='glorot_uniform'), input_shape=input_shape))
#     model.add(Dropout(0.5))
#     model.add(BatchNormalization())

#     # Second Bidirectional LSTM layer
#     model.add(Bidirectional(LSTM(64, return_sequences=True, activation='tanh')))
#     model.add(Dropout(0.5))
#     model.add(BatchNormalization())

#     # TimeDistributed Dense layers
#     model.add(TimeDistributed(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))))
#     model.add(Dropout(0.3))
#     model.add(TimeDistributed(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01))))
#     model.add(Dropout(0.3))

#     # Flatten layer
#     model.add(Flatten())

#     # Fully connected output layer
#     model.add(Dense(10, activation='softmax'))

#     return model

# %%
from tensorflow.keras import Sequential, regularizers, layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, TimeDistributed, Flatten, BatchNormalization, GlobalAveragePooling1D

def create_model(x, y):
    input_shape = (x,y)  # Shape do set de treino

    model = Sequential()

    # LSTM layers
    model.add((LSTM(64, input_shape=input_shape, return_sequences=True, activation='tanh', kernel_initializer='random_normal')))
    model.add((LSTM(32, return_sequences=True, activation='tanh')))

    # TimeDistributed Dense layers
    model.add(TimeDistributed(Dense(32, activation='tanh', kernel_regularizer=regularizers.l2(0.01))))
    model.add(Dropout(0.3))
    model.add(TimeDistributed(Dense(16, activation='tanh', kernel_regularizer=regularizers.l2(0.01))))
    model.add(Dropout(0.3))
    model.add(TimeDistributed(Dense(8, activation='tanh', kernel_regularizer=regularizers.l2(0.01))))
    
    # Pooling to reduce sequence
    model.add(Flatten())

    # Output layers
    model.add(Dense(10, activation='softmax'))

    return model

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed, GlobalAveragePooling1D
# from tensorflow.keras import regularizers
# from tensorflow.keras.layers import BatchNormalization

# def create_model1(x, y):
#     input_shape = (x, y)
#     model = Sequential()

#     # LSTM Layers with Dropout for regularization
#     model.add(LSTM(128, input_shape=input_shape, return_sequences=True, activation='tanh'))
#     model.add(Dropout(0.3))
#     model.add(LSTM(64, return_sequences=True, activation='tanh'))
#     model.add(Dropout(0.3))

#     # TimeDistributed Dense Layers with Batch Normalization
#     model.add(TimeDistributed(Dense(64, activation='tanh', kernel_regularizer=regularizers.l2(0.001))))
#     model.add(Dropout(0.4))
#     model.add(TimeDistributed(Dense(32, activation='tanh', kernel_regularizer=regularizers.l2(0.001))))
#     model.add(Dropout(0.4))
#     model.add(TimeDistributed(Dense(16, activation='tanh', kernel_regularizer=regularizers.l2(0.001))))
#     model.add(Dropout(0.4))
#     model.add(TimeDistributed(Dense(8, activation='tanh', kernel_regularizer=regularizers.l2(0.001))))
#     model.add(BatchNormalization())  # Stabilize training
#     model.add(Dropout(0.4))

#     # Pooling Layer
#     model.add(GlobalAveragePooling1D())

    

#     # Output Layer
#     model.add(Dense(10, activation='softmax'))  # Assuming 10 classes

#     return model

# %%
#model = create_bidirectional_model(345, 513)
model = create_model(87, 13)
model.summary()
# Out:
# c:\Users\guica\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 87, 64)         │        19,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 87, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 87, 32)         │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 87, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 87, 32)         │         1,056 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 87, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 87, 16)         │           528 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 87, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 87, 8)          │           136 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 696)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         6,970 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41,074 (160.45 KB)
#  Trainable params: 41,074 (160.45 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# training strategies

# %% [markdown]
# novo n2

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import keras
import numpy as np

fold_metrics = []
EPOCHS = 50
fold = 0  # Current fold to be used as test set

print(f"Fold {fold+1}:")

# Initialize lists for train/test sets
X_train, y_train = [], []
X_test, y_test = None, None

# Splitting the data into Train, Test, and Validation sets
for i in range(10):
    if i == 1:
        # Set test data
        X_test = features[i]
        y_test = label[i]
    elif i == 2:
        # validation set
        X_val = features[i]
        y_val = label[i]
        
    else:
        # Append data for training
        if len(X_train) == 0:  # Initialize for the first fold
            X_train = features[i]
            y_train = label[i]
        else:
            X_train = np.concatenate((X_train, features[i]), axis=0)
            y_train = np.concatenate((y_train, label[i]), axis=0)

# Split test set into test and validation sets
#X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=123)

# Convert data to numpy arrays if not already
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
X_val = np.array(X_val)
y_val = np.array(y_val)

# Print set shapes
print(f"X_train Shape: {X_train.shape}")
print(f"y_train Shape: {y_train.shape}")
print(f"X_test Shape: {X_test.shape}")
print(f"y_test Shape: {y_test.shape}")
print(f"X_val Shape: {X_val.shape}")
print(f"y_val Shape: {y_val.shape}")

early_stopping = EarlyStopping(monitor = 'val_accuracy', patience = 7, restore_best_weights = True)
#lr_scheduler = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.5, patience = 3, min_lr = 1e-4)

# Compile model
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(
    optimizer=optimizer, 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# Train model
LSTM = model.fit(
    X_train, y_train, 
    epochs=EPOCHS,
    batch_size=32, 
    shuffle=False, 
    validation_data=(X_val, y_val),
    callbacks = early_stopping
)

# Predict unseen data
y_pred = model.predict(X_test)

# Evaluate the model
y_pred_reshape = np.argmax(y_pred, axis=1)
y_test_reshape = np.argmax(y_test, axis=1)
TestLoss, Testacc = model.evaluate(X_test, y_test)

# Save fold results
m_metrics = {
    'loss': TestLoss, 
    'accuracy': Testacc, 
    'confusion_matrix': confusion_matrix(y_test_reshape, y_pred_reshape), 
    'history': model, 
    'history_dict': LSTM.history
}

fold_metrics.append(m_metrics)

#model.save(f"kfold_metrics_LSTM/model_fold{fold+1}.keras", save_format="keras")
save_pkl(fold_metrics, f"kfold_metrics_LSTM/metrics{fold+1}.pkl")

# Restart model to avoid memory leakage
del model
keras.backend.clear_session()

print("Done.")
# Out:
# Fold 1:
# X_train Shape: (6919, 87, 13)
# y_train Shape: (6919, 10)
# X_test Shape: (888, 87, 13)
# y_test Shape: (888, 10)
# X_val Shape: (925, 87, 13)
# y_val Shape: (925, 10)
# Epoch 1/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 39s 82ms/step - accuracy: 0.1264 - loss: 2.7898 - val_accuracy: 0.2378 - val_loss: 2.2394
# Epoch 2/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.2996 - loss: 2.1621 - val_accuracy: 0.3665 - val_loss: 1.9268
# Epoch 3/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.3645 - loss: 1.8764 - val_accuracy: 0.4292 - val_loss: 1.7398
# Epoch 4/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.4302 - loss: 1.6890 - val_accuracy: 0.4530 - val_loss: 1.6345
# Epoch 5/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.4736 - loss: 1.5760 - val_accuracy: 0.4595 - val_loss: 1.5813
# Epoch 6/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.5004 - loss: 1.4836 - val_accuracy: 0.4649 - val_loss: 1.5354
# Epoch 7/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.5192 - loss: 1.4132 - val_accuracy: 0.4703 - val_loss: 1.5166
# Epoch 8/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.5467 - loss: 1.3441 - val_accuracy: 0.4768 - val_loss: 1.4988
# Epoch 9/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.5696 - loss: 1.2801 - val_accuracy: 0.4724 - val_loss: 1.5038
# Epoch 10/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.5837 - loss: 1.2260 - val_accuracy: 0.4735 - val_loss: 1.5197
# Epoch 11/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.6039 - loss: 1.1745 - val_accuracy: 0.4778 - val_loss: 1.5379
# Epoch 12/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.6173 - loss: 1.1273 - val_accuracy: 0.4800 - val_loss: 1.5348
# Epoch 13/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.6336 - loss: 1.0883 - val_accuracy: 0.4843 - val_loss: 1.5530
# Epoch 14/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.6478 - loss: 1.0466 - val_accuracy: 0.4854 - val_loss: 1.5692
# Epoch 15/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 65ms/step - accuracy: 0.6645 - loss: 1.0035 - val_accuracy: 0.4768 - val_loss: 1.5708
# Epoch 16/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.6741 - loss: 0.9726 - val_accuracy: 0.4768 - val_loss: 1.6175
# Epoch 17/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 15s 67ms/step - accuracy: 0.6897 - loss: 0.9351 - val_accuracy: 0.4703 - val_loss: 1.6329
# Epoch 18/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.7030 - loss: 0.8947 - val_accuracy: 0.4659 - val_loss: 1.6900
# Epoch 19/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.7183 - loss: 0.8580 - val_accuracy: 0.4627 - val_loss: 1.7072
# Epoch 20/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 15s 67ms/step - accuracy: 0.7267 - loss: 0.8267 - val_accuracy: 0.4659 - val_loss: 1.7369
# Epoch 21/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.7390 - loss: 0.7998 - val_accuracy: 0.4659 - val_loss: 1.7520
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5474 - loss: 1.3959
# Fail to save data
# Done.

# %% [markdown]
# ### novo

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import keras
import numpy as np

fold_metrics = []
EPOCHS = 50
fold = 0  # Current fold to be used as test set

print(f"Fold {fold+1}:")

# Initialize lists for train/test sets
X_train, y_train = [], []
X_test, y_test = None, None

# Splitting the data into Train, Test, and Validation sets
for i in range(10):
    if i == 0:
        # Set test data
        X_test = features[i]
        y_test = label[i]
    elif i == 1:
        # validation set
        X_val = features[i]
        y_val = label[i]
        
    else:
        # Append data for training
        if len(X_train) == 0:  # Initialize for the first fold
            X_train = features[i]
            y_train = label[i]
        else:
            X_train = np.concatenate((X_train, features[i]), axis=0)
            y_train = np.concatenate((y_train, label[i]), axis=0)

# Split test set into test and validation sets
#X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=123)

# Convert data to numpy arrays if not already
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
X_val = np.array(X_val)
y_val = np.array(y_val)

# Print set shapes
print(f"X_train Shape: {X_train.shape}")
print(f"y_train Shape: {y_train.shape}")
print(f"X_test Shape: {X_test.shape}")
print(f"y_test Shape: {y_test.shape}")
print(f"X_val Shape: {X_val.shape}")
print(f"y_val Shape: {y_val.shape}")



# Compile model
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(
    optimizer=optimizer, 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# Train model
LSTM = model.fit(
    X_train, y_train, 
    epochs=EPOCHS,
    batch_size=32, 
    shuffle=False, 
    validation_data=(X_val, y_val),
   
)

# Predict unseen data
y_pred = model.predict(X_test)

# Evaluate the model
y_pred_reshape = np.argmax(y_pred, axis=1)
y_test_reshape = np.argmax(y_test, axis=1)
TestLoss, Testacc = model.evaluate(X_test, y_test)

# Save fold results
m_metrics = {
    'loss': TestLoss, 
    'accuracy': Testacc, 
    'confusion_matrix': confusion_matrix(y_test_reshape, y_pred_reshape), 
    'history': model, 
    'history_dict': LSTM.history
}

fold_metrics.append(m_metrics)

model.save(f"kfold_metrics_LSTM/model_fold{fold+1}.keras", save_format="keras")
save_pkl(fold_metrics, f"kfold_metrics_LSTM/metrics{fold+1}.pkl")

# Restart model to avoid memory leakage
del model
keras.backend.clear_session()

print("Done.")
# Out:
# Fold 1:
# X_train Shape: (7859, 130, 513)
# y_train Shape: (7859, 10)
# X_test Shape: (436, 130, 513)
# y_test Shape: (436, 10)
# X_val Shape: (437, 130, 513)
# y_val Shape: (437, 10)
# Epoch 1/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.1713 - loss: 5.3991 - val_accuracy: 0.3204 - val_loss: 3.8939
# Epoch 2/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.2625 - loss: 3.7494 - val_accuracy: 0.2929 - val_loss: 3.2224
# Epoch 3/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.2823 - loss: 3.1385 - val_accuracy: 0.3295 - val_loss: 2.7065
# Epoch 4/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.3262 - loss: 2.6818 - val_accuracy: 0.3501 - val_loss: 2.4154
# Epoch 5/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.3191 - loss: 2.4476 - val_accuracy: 0.3570 - val_loss: 2.2732
# Epoch 6/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.3631 - loss: 2.1862 - val_accuracy: 0.3387 - val_loss: 2.0972
# Epoch 7/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.3879 - loss: 2.0158 - val_accuracy: 0.4279 - val_loss: 1.9645
# Epoch 8/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.4281 - loss: 1.8686 - val_accuracy: 0.4073 - val_loss: 1.9449
# Epoch 9/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.4404 - loss: 1.7649 - val_accuracy: 0.3844 - val_loss: 2.0096
# Epoch 10/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.4523 - loss: 1.6840 - val_accuracy: 0.3753 - val_loss: 2.1914
# Epoch 11/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.4788 - loss: 1.5854 - val_accuracy: 0.4142 - val_loss: 1.8134
# Epoch 12/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.5180 - loss: 1.4919 - val_accuracy: 0.4577 - val_loss: 1.8803
# Epoch 13/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.5385 - loss: 1.4331 - val_accuracy: 0.3913 - val_loss: 1.9189
# Epoch 14/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.5617 - loss: 1.3652 - val_accuracy: 0.4256 - val_loss: 1.8020
# Epoch 15/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.5855 - loss: 1.3059 - val_accuracy: 0.4600 - val_loss: 1.7345
# Epoch 16/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.5975 - loss: 1.2413 - val_accuracy: 0.3982 - val_loss: 1.9076
# Epoch 17/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.6137 - loss: 1.2506 - val_accuracy: 0.4691 - val_loss: 2.0249
# Epoch 18/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.6481 - loss: 1.1725 - val_accuracy: 0.4371 - val_loss: 1.9766
# Epoch 19/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.6955 - loss: 1.0199 - val_accuracy: 0.3707 - val_loss: 2.5258
# Epoch 20/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.6961 - loss: 1.0064 - val_accuracy: 0.4325 - val_loss: 2.0853
# Epoch 21/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.7196 - loss: 0.9617 - val_accuracy: 0.4783 - val_loss: 1.8290
# Epoch 22/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.7524 - loss: 0.8787 - val_accuracy: 0.4577 - val_loss: 2.3965
# Epoch 23/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.7707 - loss: 0.8212 - val_accuracy: 0.4394 - val_loss: 2.7934
# Epoch 24/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.7917 - loss: 0.7488 - val_accuracy: 0.4760 - val_loss: 2.4240
# Epoch 25/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.8142 - loss: 0.6880 - val_accuracy: 0.4188 - val_loss: 2.7692
# Epoch 26/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.8055 - loss: 0.7087 - val_accuracy: 0.4439 - val_loss: 2.2358
# Epoch 27/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.7961 - loss: 0.7519 - val_accuracy: 0.4600 - val_loss: 2.2859
# Epoch 28/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.8238 - loss: 0.6603 - val_accuracy: 0.4508 - val_loss: 2.1478
# Epoch 29/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.8505 - loss: 0.6054 - val_accuracy: 0.4508 - val_loss: 2.2518
# Epoch 30/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.8563 - loss: 0.5899 - val_accuracy: 0.4989 - val_loss: 2.3491
# Epoch 31/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.8754 - loss: 0.5217 - val_accuracy: 0.4714 - val_loss: 2.8894
# Epoch 32/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - accuracy: 0.8717 - loss: 0.5258 - val_accuracy: 0.4371 - val_loss: 3.9711
# Epoch 33/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.8993 - loss: 0.4430 - val_accuracy: 0.4416 - val_loss: 2.8329
# Epoch 34/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.9192 - loss: 0.3723 - val_accuracy: 0.4874 - val_loss: 3.7955
# Epoch 35/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.9314 - loss: 0.3453 - val_accuracy: 0.4600 - val_loss: 3.4301
# Epoch 36/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.9391 - loss: 0.3155 - val_accuracy: 0.4554 - val_loss: 3.4027
# Epoch 37/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - accuracy: 0.9153 - loss: 0.3798 - val_accuracy: 0.4600 - val_loss: 3.0361
# Epoch 38/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.8552 - loss: 0.5526 - val_accuracy: 0.4256 - val_loss: 3.0694
# Epoch 39/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.8990 - loss: 0.4485 - val_accuracy: 0.4485 - val_loss: 3.0290
# Epoch 40/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9216 - loss: 0.3746 - val_accuracy: 0.4416 - val_loss: 3.7046
# Epoch 41/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1090s 9s/step - accuracy: 0.9481 - loss: 0.2936 - val_accuracy: 0.4256 - val_loss: 3.9104
# Epoch 42/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.9623 - loss: 0.2451 - val_accuracy: 0.4554 - val_loss: 3.1269
# Epoch 43/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9501 - loss: 0.2660 - val_accuracy: 0.5034 - val_loss: 2.8897
# Epoch 44/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.9188 - loss: 0.4092 - val_accuracy: 0.4211 - val_loss: 3.5514
# Epoch 45/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9167 - loss: 0.3869 - val_accuracy: 0.5217 - val_loss: 3.3405
# Epoch 46/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9467 - loss: 0.2960 - val_accuracy: 0.4165 - val_loss: 3.6576
# Epoch 47/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9613 - loss: 0.2466 - val_accuracy: 0.4554 - val_loss: 3.4967
# Epoch 48/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9323 - loss: 0.3188 - val_accuracy: 0.4874 - val_loss: 3.7885
# Epoch 49/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9582 - loss: 0.2579 - val_accuracy: 0.4188 - val_loss: 4.1381
# Epoch 50/50
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9697 - loss: 0.2112 - val_accuracy: 0.4874 - val_loss: 3.8328
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 12s 472ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.4398 - loss: 3.9125
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 86
#      76 m_metrics = {
#      77     'loss': TestLoss,
#      78     'accuracy': Testacc,
#    (...)
#      81     'history_dict': LSTM.history
#      82 }
#      84 fold_metrics.append(m_metrics)
# ---> 86 model.save(f"kfold_metrics_LSTM/model_fold{fold+1}.keras", save_format="keras")
#      87 save_pkl(fold_metrics, f"kfold_metrics_LSTM/metrics{fold+1}.pkl")
#      89 # Restart model to avoid memory leakage
#
# File c:\Users\guica\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\guica\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:141, in save_model(model, filepath, weights_format, zipped)
#     139         f.write(zip_filepath.getvalue())
#     140 else:
# --> 141     with open(filepath, "wb") as f:
#     142         _save_model_to_fileobj(model, f, weights_format)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kfold_metrics_LSTM/model_fold1.keras'

# %%
epochs = range(1, EPOCHS + 1)

fig, ax = plt.subplots(len(fold_metrics), 2, figsize=(10, 5*len(fold_metrics)))


for i in range(0,len(fold_metrics)):
    history_dict = fold_metrics[i].get('history_dict')
    loss_values=history_dict['loss']
    acc_values=history_dict['accuracy']
    val_loss_values = history_dict['val_loss']
    val_acc_values = history_dict['val_accuracy']

    ax[0].plot(epochs,loss_values,'co',label='Training Loss')
    ax[0].plot(epochs,val_loss_values,'m', label='Validation Loss')
    ax[0].set_title('Training and validation loss on fold '+str(i+1)+' of 10')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend()

    ax[1].plot(epochs,acc_values,'co', label='Training accuracy')
    ax[1].plot(epochs,val_acc_values,'m', label='Validation accuracy')
    ax[1].set_title('Training and validation accuracy on fold '+str(i+1)+' of 10')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Accuracy')
    ax[1].legend()
    plt.show()

# %% [markdown]
# ### antigo

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import keras
fold_metrics = []
EPOCHS = 50
fold = 0

f = "fold" + str(fold+1)
print("Fold "+str(fold+1)+":")

X_train, y_train = [], []
X_test, y_test = [], []
    
# Splitting the data into Test, Validation and Training sets
for i in range(10):
    if( i != fold):
        X_train += features[i].tolist()
        y_train.extend(label[i])
        
    else:
        X_test = features[i]
        y_test = labels[i]

    
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
        
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size = 0.5, random_state = 123)

# Print sets shapes
print(f"X_train Shape: {X_train.shape}")
print(f"X_test Shape: {X_test.shape}")
print(f"X_val Shape: {X_val.shape}")


optimizer = keras.optimizers.Adam(learning_rate = 0.001)
model.compile(
    optimizer = optimizer, 
    loss = 'categorical_crossentropy', 
    metrics=['accuracy']
)

# Train model
LSTM = model.fit(
    X_train, y_train, 
    epochs = EPOCHS,
    batch_size = 64, 
    shuffle = False, 
    validation_data=(X_val, y_val)
)

# Predict unseen data
y_pred = model.predict(X_test)

y_pred_reshape = np.argmax(y_pred, axis=1)
y_test_reshape = np.argmax(y_test, axis=1)
TestLoss, Testacc = model.evaluate(X_test, y_test)

# Save fold results
m_metrics = {
    'loss': TestLoss, 
    'accuracy': Testacc, 
    'confusion_matrix': confusion_matrix(y_test_reshape, y_pred_reshape), 
    'history': model, 'history_dict': LSTM.history
}

fold_metrics.append(m_metrics)

model.save(f"kfold_metrics_LSTM/model_fold{fold+1}.keras", save_format="keras")
save_pkl(fold_metrics, f"kfold_metrics_LSTM/metrics{fold+1}.pkl")

# restart model to avoid memory leakage
del model 

print("Done.")
# Out:
# Fold 1:

# %% [markdown]
# performance evaluation
